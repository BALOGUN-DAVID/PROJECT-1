# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Board = "./billboard.csv"
Board = pd.read_csv(Board)
Board
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
Bill_Board = pd.melt(Board, id_vars=["year","artist","track","time","date.entered"],  var_name = "week", value_name = "num_record") 
Bill_Board
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  num_record
# 0       wk1        87.0
# 1       wk1        91.0
# ...

# %%
Bill_Board.isnull()
# Out:
#         year  artist  track   time  date.entered   week  num_record
# 0      False   False  False  False         False  False       False
# 1      False   False  False  False         False  False       False
# 2      False   False  False  False         False  False       False
# 3      False   False  False  False         False  False       False
# 4      False   False  False  False         False  False       False
# ...      ...     ...    ...    ...           ...    ...         ...
# 24087  False   False  False  False         False  False        True
# 24088  False   False  False  False         False  False        True
# 24089  False   False  False  False         False  False        True
# 24090  False   False  False  False         False  False        True
# 24091  False   False  False  False         False  False        True
#
# [24092 rows x 7 columns]

# %%
Bill_Board.iloc[[20,90,80],[0,1,3]]
# Out:
#     year             artist  time
# 20  2000              Avant  4:28
# 90  2000          Eiffel 65  3:29
# 80  2000  Dixie Chicks, The  5:12

# %%
import numpy as np

# %%
import numpy as np
arr1 = np.array([23,45,90,57,83])
arr2 = np.array([28,9,779,297,67])

# %%
add = np.add(arr1, arr2)
add
# Out:
# array([ 51,  54, 869, 354, 150])

# %%
div = np.divide(arr1, arr2)
div
# Out:
# array([0.82142857, 5.        , 0.11553273, 0.19191919, 1.23880597])

# %%
mat = np.array ([[1,2,3],[2,4,7],[4,6,7]])
mat2 = np.array([[2,9,7],[1,8,7],[6,2,8]])
mat3 = np.array([[3,8,2],[4,6,7],[3,6,9]])
matpro = np.matmul(mat, mat2, mat3)
matpro
# Out:
# array([[ 22,  31,  45],
#        [ 50,  64,  98],
#        [ 56,  98, 126]])

# %%
np.mean(matpro)
# Out:
# 65.55555555555556

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe ["x"].plot()
plt.xlabel("Bins")
plt.ylabel("value of x")
plt.title("line chart")
plt.show()

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.groupby("day").agg({"tip":'sum'}).plot(marker = "|" )
plt.title("tips given")
plt.xlabel('Amount') 
plt.ylabel("Total")
plt.show()

# %%
plt.scatter(tips["total_bill"],tips["tip"], s = 59, c = "purple", marker = "3")
plt.xlabel("Total bill")
plt.ylabel("Tip")
plt.show()

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips, s= 80, marker = "p", hue ="sex")
plt.show()

# %%
sns.barplot(x = "sex", y = "tip", data = tips)
plt.show()

# %%
sns.boxplot(x = "sex", y = "tip", data = tips)
plt.show()

# %%
sns.catplot (x = "sex", y = "tip", data = tips, kind = "violin")
plt.show()
plt.yticks([ ])

sns.countplot(x = "day", data = tips)
plt.show()
plt.yticks([ ])

sns.boxplot(x = "sex", y = "tip", data = tips)
plt.show()
plt.yticks([ ])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
sns.countplot(x = "day", data = tips)
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
fig, ax = plt.subplots(2,2)
ax[0, 0].plot(data_1['x'], data_1['y'], 'o')

ax[0, 0].set_title('Dataset I')

ax[0, 1].plot(data_2['x'], data_2['y'], 'ro')
ax[0, 1].set_title('Dataset II')

ax[1, 0].plot(data_3['x'], data_3['y'], 'go')


ax[1, 1].plot(data_4['x'], data_4['y'], 'o')


plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.hist(tips['total_bill'])
axes.set_xlabel('Frequency')
axes.set_ylabel('Total Bill')
axes.set_title('Histogram of Total Bill')
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(tips['total_bill'])
ax.set_xlabel("Frequency")
ax.set_ylabel("Total Bill")
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot([tips_fem['tip'], tips_ma['tip']],
          labels = ['Female', 'Male'])
ax.set_xlabel('Sex')
ax.set_ylabel('Tip')
ax.set_title('Boxplot of Tip for each Sex')
plt.show()

# %%
sns.distplot(tips['tip'], kde = False)
plt.show()

# %%
# display a plot showing the frequency of each day in the tips data
sns.countplot(tips['day'])
plt.ylabel('Frequency')
plt.title('Count Plot of Day variable')
plt.show()

# %%
# display boxplot, barplot,and violin plots
sns.catplot(x = 'sex', y = 'tip', data = tips, kind = 'violin')
plt.show()

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'bar')
plt.show()

# %%
fig, ax  = plt.subplots()
ax = sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
ax.set_title('Scatter plot of Total bill vs Tip')
plt.show()

# %%
plt.savefig("scatter.png")

# %%
import pandas as pd

# %%
shiftdata = "./shifts.xlsx"
shiftdata = pd.read_excel(shiftdata)
shiftdata
# Out:
#      Shift Region Sales Rep  Product  Cost per unit  Units Sold
# 0        1  South    Meggan    Paper             15         163
# 1        1  South    Charis  Stapler             25         108
# 2        1  South    Shayne   Pencil              5         118
# 3        1  North   Krystin      Pen             10          37
# 4        1  South       Leo    Paper             15         131
# ..     ...    ...       ...      ...            ...         ...
# 391      1   East     Diann   Binder             30          46
# 392      1   East   Cordell   Binder             30          91
# 393      1  North  Jesusita   Binder             30         200
# 394      1  South      Dina    Paper             15         166
# 395      1   East   Jenifer   Folder             17          89
#
# [396 rows x 6 columns]

# %%
shiftdata.nunique()
# Out:
# Shift              4
# Region             4
# Sales Rep         43
# Product            6
# Cost per unit     26
# Units Sold       109
# dtype: int64

# %%
#Using the shifts.xlsx data, find the total Units sold for each of the regions
shiftdata.groupby("Region").agg({"Units Sold": 'sum'})
# Out:
#         Units Sold
# Region
# East         14228
# North        14675
# South        13752
# West         11255

# %%
#Find the top three sales reps that had the highest units sold in total, also listing the total units sold by each of them
rep = shiftdata.groupby("Sales Rep").agg({"Units Sold":'sum'})
rep.sort_values(by = "Units Sold", ascending = False)
# Out:
#            Units Sold
# Sales Rep
# Deandra          2915
# Jesusita         2116
# Natashia         2082
# Estelle          2080
# Delpha           2075
# Jimmy            2048
# Shayne           2015
# Shirlene         1939
# Nisha            1840
# Caleb            1764
# Jenifer          1709
# Krystin          1507
# Keitha           1472
# Winter           1445
# Martha           1401
# Dina             1396
# Shelli           1376
# Chaya            1346
# Cristen          1304
# Tyree            1268
# Claudine         1232
# Betsy            1209
# Dorthea          1193
# Lisbeth          1144
# Damion           1143
# Ami              1056
# Kaci             1032
# Takisha          1004
# Charis            980
# Kelvin            952
# Nolan             896
# Diann             877
# Lola              804
# Willa             800
# Lashon            764
# Leo               756
# Meggan            652
# Cordell           538
# Von               536
# Raye              464
# ...

# %%
#Using visualization, find the product with the highest unit sold and state the units sold
shiftdata
# Out:
#      Shift Region Sales Rep  Product  Cost per unit  Units Sold
# 0        1  South    Meggan    Paper             15         163
# 1        1  South    Charis  Stapler             25         108
# 2        1  South    Shayne   Pencil              5         118
# 3        1  North   Krystin      Pen             10          37
# 4        1  South       Leo    Paper             15         131
# ..     ...    ...       ...      ...            ...         ...
# 391      1   East     Diann   Binder             30          46
# 392      1   East   Cordell   Binder             30          91
# 393      1  North  Jesusita   Binder             30         200
# 394      1  South      Dina    Paper             15         166
# 395      1   East   Jenifer   Folder             17          89
#
# [396 rows x 6 columns]

# %%
shiftdata.groupby(["Product","Region"]).agg({"Units Sold":'sum'})
sns.scatterplot(x = "Product", y = "Units Sold", data = shiftdata, hue = "Product")
plt.title("Product by unit sold")
# Out:
# Text(0.5, 1.0, 'Product by unit sold')

# %%
Res = sns.catplot(x = "Product", y = "Units Sold", data = shiftdata, legend=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
shifts.groupby("Sales Rep")["Units Sold"].sum()
# Out:
# Sales Rep
# Adrian       444
# Ami         1056
# Betsy       1209
# Caleb       1764
# Charis       980
# Chaya       1346
# Claudine    1232
# Cordell      538
# Cristen     1304
# Damion      1143
# Deandra     2915
# Delpha      2075
# Diann        877
# Dina        1396
# Dorthea     1193
# Estelle     2080
# Jenifer     1709
# Jesusita    2116
# Jimmy       2048
# Kaci        1032
# Keitha      1472
# Kelvin       952
# Krystin     1507
# Lashon       764
# Leo          756
# Lisbeth     1144
# Lola         804
# Martha      1401
# Meggan       652
# Natashia    2082
# Nisha       1840
# Nola         168
# Nolan        896
# Raye         464
# Shayne      2015
# Shelli      1376
# Shirlene    1939
# Takisha     1004
# Tyree       1268
# Von          536
# Willa        800
# Willette     168
# Winter      1445
# Name: Units Sold, dtype: int64
